# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 50
## Install xlrd package to load Excel files
# conda install openpyxl
## conda install xlrd

# %% [markdown]
# - Aggregate data into one Data Frame using Pandas.

# %%
file1 = pd.read_csv('Data/file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
#file1["State"] = file1["ST"]
file1 = file1.rename(columns={"GENDER":"Gender"})
file1
# Out:
#      Customer          ST Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
# percentage in costumer life value could give us problems, let's get rid of it

# %%
file1["Customer Lifetime Value"] = file1["Customer Lifetime Value"].astype("string")
file1["Customer Lifetime Value"] = file1["Customer Lifetime Value"].str.rstrip("%")

# %%
file2 = pd.read_csv('Data/file2.csv')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
file2 = file2.rename(columns={"GENDER":"Gender"})
file2
# Out:
#     Customer          ST Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
file2["Customer Lifetime Value"] = file2["Customer Lifetime Value"].astype("string")
file2["Customer Lifetime Value"] = file2["Customer Lifetime Value"].str.rstrip("%")
file2
# Out:
#     Customer          ST Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor               323912.47   16061
# 1    CW49887  California      F    Master               462680.11   79487
# 2    MY31220  California      F   College               899704.02   54230
# 3    UH35128      Oregon      F   College              2580706.30   71210
# 4    WH52799     Arizona      F   College               380812.21   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master               847141.75   63513
# 992  BS91566     Arizona      F   College               543121.91   58161
# 993  IL40123      Nevada      F   College               568964.41   83640
# 994  MY32149  California      F    Master               368672.38       0
# 995  SA91515  California      M  Bachelor               399258.39       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
file3 = pd.read_csv('Data/file3.csv')
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
file3= file3.rename(columns={"State":"ST"})

# %%
def load_original_data():
    return pd.concat([file1,file2,file3], axis=0)

# %%
df = load_original_data()
df
# Out:
#      Customer          ST Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                       <NA>      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                   23406  71941.0                  73.0
# 7066                 3096.51  21604.0                  79.0
# 7067                 8163.89      0.0                  85.0
# 7068                 7524.44  21941.0                  96.0
# 7069                 2611.84      0.0                  77.0
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [12074 rows x 11 columns]

# %% [markdown]
# ## Standardizing header names

# %%
df.columns=[i.lower() for i in df.columns]
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                       <NA>      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                   23406  71941.0                  73.0
# 7066                 3096.51  21604.0                  79.0
# 7067                 8163.89      0.0                  85.0
# 7068                 7524.44  21941.0                  96.0
# 7069                 2611.84      0.0                  77.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [12074 rows x 11 columns]

# %% [markdown]
# ## Deleting and rearranging columns

# %%
df.drop(["customer"], axis=1,inplace=True)
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %%
#df["customer lifetime value"] = df["customer lifetime value"].replace({'%',' '})
#NOT WORKING

# %%
#df["education"]  = df["education"].replace({'Master': 'M'})

# %% [markdown]
# ## Working with data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
#df["customer lifetime value"] = df["customer lifetime value"].astype("string")

# %%
#df["customer lifetime value"] = df["customer lifetime value"].str.rstrip("%")

# %%
df["education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
sorted(df)
# Out:
# ['customer lifetime value',
#  'education',
#  'gender',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'st',
#  'total claim amount',
#  'vehicle class']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
#df["customer lifetime value"].mean()

# %%
df["customer lifetime value"].isnull().sum(axis = 0)
# Out:
# 2944

# %% [markdown]
# ## Clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %%
df["number of open complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
df["number of open complaints"] = df["number of open complaints"].astype("string")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   string
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(6), string(1)
# memory usage: 1.0+ MB

# %%
#df["number of open complaints"] = df["number of open complaints"].str.strip("/")

#df["number of open complaints"] = df["number of open complaints"].str.rstrip("/00")

# %%
#(df["number of open complaints"].str.startswith("1/"))

# %%
df["number of open complaints"].unique()
# Out:
# <StringArray>
# ['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00',     <NA>,
#       '0',      '2',      '3',      '1',      '5',      '4']
# Length: 13, dtype: string

# %%
df["number of open complaints"] = df["number of open complaints"].str[:3].str[-1]   #slice just first 3 characters and then just keep the last one

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                         0   Personal Auto
# 1         0.0                  94.0                         0   Personal Auto
# 2     48767.0                 108.0                         0   Personal Auto
# 3         0.0                 106.0                         0  Corporate Auto
# 4     36357.0                  68.0                         0   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %%
df["number of open complaints"].unique()
# Out:
# <StringArray>
# ['0', '2', '1', '3', '5', '4', <NA>]
# Length: 7, dtype: string

# %%
df["number of open complaints"].value_counts()
# Out:
# 0    7255
# 1    1012
# 2     376
# 3     290
# 4     148
# 5      56
# Name: number of open complaints, dtype: Int64

# %%
#WE HAVE TO CHANGE TO STRING

# %% [markdown]
# ## Filtering data and Correcting typos

# %%
df["gender"].value_counts()
# Out:
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
df["gender"] = df["gender"].replace({'Male': 'M', 'female': 'F', 'Femal': 'F'})
df["gender"].value_counts()
# Out:
# F    4607
# M    4408
# Name: gender, dtype: int64

# %%
df["st"].value_counts()
# Out:
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: st, dtype: int64

# %%
df["st"] = df["st"].replace({'AZ': 'Arizona', 'WA': 'Washington','Cali': 'California'})
df["st"].value_counts()
# Out:
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: st, dtype: int64

# %%
df["education"].value_counts()
# Out:
# Bachelor                2719
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Bachelors                 24
# Name: education, dtype: int64

# %%
df["policy type"].value_counts()
# Out:
# Personal Auto     6792
# Corporate Auto    1965
# Special Auto       380
# Name: policy type, dtype: int64

# %%
df["vehicle class"].value_counts()
# Out:
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Sports Car        483
# Luxury SUV        182
# Luxury Car        161
# Name: vehicle class, dtype: int64

# %% [markdown]
# ## Removing duplicates

# %%
#df = df.duplicated()
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                         0   Personal Auto
# 1         0.0                  94.0                         0   Personal Auto
# 2     48767.0                 108.0                         0   Personal Auto
# 3         0.0                 106.0                         0  Corporate Auto
# 4     36357.0                  68.0                         0   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 3198

# %%
df = df[~df.duplicated()]
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                         0   Personal Auto
# 1         0.0                  94.0                         0   Personal Auto
# 2     48767.0                 108.0                         0   Personal Auto
# 3         0.0                 106.0                         0  Corporate Auto
# 4     36357.0                  68.0                         0   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %% [markdown]
# ## Replacing null values

# %%
round(df.isna().sum()/len(df),4)*100  #show percentage of null values in a column
# Out:
# st                           0.01
# gender                       1.39
# education                    0.01
# customer lifetime value      0.09
# income                       0.01
# monthly premium auto         0.01
# number of open complaints    0.01
# policy type                  0.01
# vehicle class                0.01
# total claim amount           0.01
# dtype: float64

# %%
df["customer lifetime value"].value_counts()
# Out:
# 9031.214859          6
# 5096.673223          6
# 26197.41498          6
# 552821.28            5
# 2659.70565           5
#                     ..
# 9410.670129          1
# 6418.24871           1
# 9414.119587000001    1
# 9415.901706999999    1
# 7234.142951999999    1
# Name: customer lifetime value, Length: 8211, dtype: int64

# %%
df["customer lifetime value"].isna().sum()
# Out:
# 8

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                         0   Personal Auto
# 1         0.0                  94.0                         0   Personal Auto
# 2     48767.0                 108.0                         0   Personal Auto
# 3         0.0                 106.0                         0  Corporate Auto
# 4     36357.0                  68.0                         0   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %% [markdown]
# Correcting data types
# With to_numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8876 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         8875 non-null   object
#  1   gender                     8753 non-null   object
#  2   education                  8875 non-null   object
#  3   customer lifetime value    8868 non-null   object
#  4   income                     8875 non-null   float64
#  5   monthly premium auto       8875 non-null   float64
#  6   number of open complaints  8875 non-null   string
#  7   policy type                8875 non-null   object
#  8   vehicle class              8875 non-null   object
#  9   total claim amount         8875 non-null   float64
# dtypes: float64(3), object(6), string(1)
# memory usage: 762.8+ KB

# %%
#df["customer lifetime value"]= pd.to_numeric(df["customer lifetime value"])
#df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'],errors='coerce')

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                         0   Personal Auto
# 1         0.0                  94.0                         0   Personal Auto
# 2     48767.0                 108.0                         0   Personal Auto
# 3         0.0                 106.0                         0  Corporate Auto
# 4     36357.0                  68.0                         0   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %%
df["number of open complaints"]= pd.to_numeric(df["number of open complaints"],errors='coerce')
# Out:
# <ipython-input-53-ec026bf3129c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["number of open complaints"]= pd.to_numeric(df["number of open complaints"],errors='coerce')

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto  number of open complaints  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067      0.0                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069      0.0                  77.0                        0.0
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car          198.234764
# 7066  Corporate Auto  Four-Door Car          379.200000
# 7067  Corporate Auto  Four-Door Car          790.784983
# 7068   Personal Auto  Four-Door Car          691.200000
# 7069  Corporate Auto   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8876 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         8875 non-null   object
#  1   gender                     8753 non-null   object
#  2   education                  8875 non-null   object
#  3   customer lifetime value    8868 non-null   object
#  4   income                     8875 non-null   float64
#  5   monthly premium auto       8875 non-null   float64
#  6   number of open complaints  8875 non-null   float64
#  7   policy type                8875 non-null   object
#  8   vehicle class              8875 non-null   object
#  9   total claim amount         8875 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 762.8+ KB

# %%
#df["customer lifetime value"].mean()

# %%
#round_mean = round(df["customer lifetime value"].mean(),2)
#round_mean

# %% [markdown]
# Replace missing values with means of the column

# %%
#df["customer lifetime value"] = df["customer lifetime value"].fillna(round_mean)
#df["customer lifetime value"].isna().sum()

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                    <NA>
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto  number of open complaints  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067      0.0                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069      0.0                  77.0                        0.0
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car          198.234764
# 7066  Corporate Auto  Four-Door Car          379.200000
# 7067  Corporate Auto  Four-Door Car          790.784983
# 7068   Personal Auto  Four-Door Car          691.200000
# 7069  Corporate Auto   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %%
#columns = ["income","monthly premium auto", "number of open complaints","customer lifetime value", "total claim amount"]
#for i in columns:
#    df["i"] = df["i"].fillna(df["i"].mean())

# %%
round(df.isna().sum()/len(df),4)*100
# Out:
# st                           0.01
# gender                       1.39
# education                    0.01
# customer lifetime value      0.09
# income                       0.01
# monthly premium auto         0.01
# number of open complaints    0.01
# policy type                  0.01
# vehicle class                0.01
# total claim amount           0.01
# dtype: float64

# %%
df["income"].value_counts()
# Out:
# 0.0        2256
# 95697.0      12
# 26876.0       8
# 61108.0       8
# 24910.0       7
#            ...
# 79157.0       1
# 96721.0       1
# 29950.0       1
# 89398.0       1
# 24743.0       1
# Name: income, Length: 5655, dtype: int64

# %%
#we can say that an income = 0 is like an NaN, let's replace with the mean of the others

# %%
mean_without_zeros = df["income"][df["income"] > 0].mean()
mean_without_zeros
# Out:
# 50714.91071158785

# %%
df["income"] = df["income"].astype("string")
# Out:
# <ipython-input-65-a5e55e08cd8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["income"] = df["income"].astype("string")

# %%
df["income"] = df["income"].replace({'0.0': '50716'})
# Out:
# <ipython-input-66-fb11357a69eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["income"] = df["income"].replace({'0.0': '50716'})

# %%
#df["income"] = df["income"].fillna(df["income"].mean())
df["monthly premium auto"] = df["monthly premium auto"].fillna(df["monthly premium auto"].mean())
df["number of open complaints"] = df["number of open complaints"].fillna(df["number of open complaints"].mean())
df["customer lifetime value"] = df["customer lifetime value"].fillna(0)  #we just have 1 NaN, lets replace with 0 in order to convert the column to int
# Out:
# <ipython-input-67-08b5a1f526f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["monthly premium auto"] = df["monthly premium auto"].fillna(df["monthly premium auto"].mean())
# <ipython-input-67-08b5a1f526f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["number of open complaints"] = df["number of open complaints"].fillna(df["number of open complaints"].mean())
# <ipython-input-67-08b5a1f526f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"] = df["customer lifetime value"].fillna(0)  #we just have 1 NaN, lets replace with 0 in order to convert the column to int

# %%
df
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                       0
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        income  monthly premium auto  number of open complaints  \
# 0       50716                1000.0                        0.0
# 1       50716                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3       50716                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067    50716                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069    50716                  77.0                        0.0
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car          198.234764
# 7066  Corporate Auto  Four-Door Car          379.200000
# 7067  Corporate Auto  Four-Door Car          790.784983
# 7068   Personal Auto  Four-Door Car          691.200000
# 7069  Corporate Auto   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8876 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         8875 non-null   object
#  1   gender                     8753 non-null   object
#  2   education                  8875 non-null   object
#  3   customer lifetime value    8876 non-null   object
#  4   income                     8875 non-null   object
#  5   monthly premium auto       8876 non-null   float64
#  6   number of open complaints  8876 non-null   float64
#  7   policy type                8875 non-null   object
#  8   vehicle class              8875 non-null   object
#  9   total claim amount         8875 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 762.8+ KB

# %%
df["customer lifetime value"] = df["customer lifetime value"].astype(float)
# Out:
# <ipython-input-70-ffcf0882326b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"] = df["customer lifetime value"].astype(float)

# %%
df["customer lifetime value"] = df["customer lifetime value"].astype(int)
df["customer lifetime value"] = df["customer lifetime value"].astype(float)
# Out:
# <ipython-input-71-64e17a68a5da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"] = df["customer lifetime value"].astype(int)
# <ipython-input-71-64e17a68a5da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"] = df["customer lifetime value"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8876 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         8875 non-null   object
#  1   gender                     8753 non-null   object
#  2   education                  8875 non-null   object
#  3   customer lifetime value    8876 non-null   float64
#  4   income                     8875 non-null   object
#  5   monthly premium auto       8876 non-null   float64
#  6   number of open complaints  8876 non-null   float64
#  7   policy type                8875 non-null   object
#  8   vehicle class              8875 non-null   object
#  9   total claim amount         8875 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 762.8+ KB

# %% [markdown]
# ## Activity 2

# %% [markdown]
# ## Bucketing the data

# %% [markdown]
# Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# %%
df
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      0.0
# 1        Arizona      F              Bachelor                 697953.0
# 2         Nevada      F              Bachelor                1288743.0
# 3     California      M              Bachelor                 764586.0
# 4     Washington      M  High School or Below                 536307.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                  23405.0
# 7066  California      F               College                   3096.0
# 7067  California      M              Bachelor                   8163.0
# 7068  California      M               College                   7524.0
# 7069  California      M               College                   2611.0
#
#        income  monthly premium auto  number of open complaints  \
# 0       50716                1000.0                        0.0
# 1       50716                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3       50716                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067    50716                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069    50716                  77.0                        0.0
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car          198.234764
# 7066  Corporate Auto  Four-Door Car          379.200000
# 7067  Corporate Auto  Four-Door Car          790.784983
# 7068   Personal Auto  Four-Door Car          691.200000
# 7069  Corporate Auto   Two-Door Car          369.600000
#
# [8876 rows x 10 columns]

# %%
#for state in states:
    #if state == 'California'

# %%
df['st'] = df['st'].replace(['California', 'Orengon', 'Washington', 'Arizona'], ['West Region', 'North West', 'East', 'Central'])
# Out:
# <ipython-input-75-e5f924aab4ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['st'] = df['st'].replace(['California', 'Orengon', 'Washington', 'Arizona'], ['West Region', 'North West', 'East', 'Central'])

# %%
df.isna().sum()
# Out:
# st                             1
# gender                       123
# education                      1
# customer lifetime value        0
# income                         1
# monthly premium auto           0
# number of open complaints      0
# policy type                    1
# vehicle class                  1
# total claim amount             1
# dtype: int64

# %% [markdown]
# ## Standardizing the data

# %% [markdown]
# Use string functions to standardize the text data (lower case)

# %%
df = df.applymap(lambda x:x.lower() if type(x) == str else x)
df
# Out:
#                st gender             education  customer lifetime value  \
# 0            east    NaN                master                      0.0
# 1         central      f              bachelor                 697953.0
# 2          nevada      f              bachelor                1288743.0
# 3     west region      m              bachelor                 764586.0
# 4            east      m  high school or below                 536307.0
# ...           ...    ...                   ...                      ...
# 7065  west region      m              bachelor                  23405.0
# 7066  west region      f               college                   3096.0
# 7067  west region      m              bachelor                   8163.0
# 7068  west region      m               college                   7524.0
# 7069  west region      m               college                   2611.0
#
#        income  monthly premium auto  number of open complaints  \
# 0       50716                1000.0                        0.0
# 1       50716                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3       50716                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067    50716                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069    50716                  77.0                        0.0
#
#          policy type  vehicle class  total claim amount
# 0      personal auto  four-door car            2.704934
# 1      personal auto  four-door car         1131.464935
# 2      personal auto   two-door car          566.472247
# 3     corporate auto            suv          529.881344
# 4      personal auto  four-door car           17.269323
# ...              ...            ...                 ...
# 7065   personal auto  four-door car          198.234764
# 7066  corporate auto  four-door car          379.200000
# 7067  corporate auto  four-door car          790.784983
# 7068   personal auto  four-door car          691.200000
# 7069  corporate auto   two-door car          369.600000
#
# [8876 rows x 10 columns]

# %% [markdown]
# ## Activity 3

# %% [markdown]
# - Which columns are numerical?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8876 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         8875 non-null   object
#  1   gender                     8753 non-null   object
#  2   education                  8875 non-null   object
#  3   customer lifetime value    8876 non-null   float64
#  4   income                     8875 non-null   object
#  5   monthly premium auto       8876 non-null   float64
#  6   number of open complaints  8876 non-null   float64
#  7   policy type                8875 non-null   object
#  8   vehicle class              8875 non-null   object
#  9   total claim amount         8875 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 762.8+ KB

# %%
df.select_dtypes(float)
# Out:
#       customer lifetime value  monthly premium auto  \
# 0                         0.0                1000.0
# 1                    697953.0                  94.0
# 2                   1288743.0                 108.0
# 3                    764586.0                 106.0
# 4                    536307.0                  68.0
# ...                       ...                   ...
# 7065                  23405.0                  73.0
# 7066                   3096.0                  79.0
# 7067                   8163.0                  85.0
# 7068                   7524.0                  96.0
# 7069                   2611.0                  77.0
#
#       number of open complaints  total claim amount
# 0                           0.0            2.704934
# 1                           0.0         1131.464935
# 2                           0.0          566.472247
# 3                           0.0          529.881344
# 4                           0.0           17.269323
# ...                         ...                 ...
# 7065                        0.0          198.234764
# 7066                        0.0          379.200000
# 7067                        3.0          790.784983
# 7068                        0.0          691.200000
# 7069                        0.0          369.600000
#
# [8876 rows x 4 columns]

# %% [markdown]
# - Which columns are categorical?

# %%
df.select_dtypes(object)
# Out:
#                st gender             education   income     policy type  \
# 0            east    NaN                master    50716   personal auto
# 1         central      f              bachelor    50716   personal auto
# 2          nevada      f              bachelor  48767.0   personal auto
# 3     west region      m              bachelor    50716  corporate auto
# 4            east      m  high school or below  36357.0   personal auto
# ...           ...    ...                   ...      ...             ...
# 7065  west region      m              bachelor  71941.0   personal auto
# 7066  west region      f               college  21604.0  corporate auto
# 7067  west region      m              bachelor    50716  corporate auto
# 7068  west region      m               college  21941.0   personal auto
# 7069  west region      m               college    50716  corporate auto
#
#       vehicle class
# 0     four-door car
# 1     four-door car
# 2      two-door car
# 3               suv
# 4     four-door car
# ...             ...
# 7065  four-door car
# 7066  four-door car
# 7067  four-door car
# 7068  four-door car
# 7069   two-door car
#
# [8876 rows x 6 columns]

# %%
#education,

# %%
#df.select_dtypes

# %%
#df.get_numeric_data()

# %% [markdown]
# ## Datetime format
# Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %% [markdown]
# ## Activity 4

# %% [markdown]
# From now, we work in a cleaned version of the csv

# %%
df_clean= pd.read_csv('Data/Data_Marketing_Customer_Analysis_Round3.csv')
df_clean
# Out:
#        Unnamed: 0       region  customer_lifetime_value response  coverage  \
# 0               0      central                     4809       no     basic
# 1               1  west region                     2228       no     basic
# 2               2         east                    14947       no     basic
# 3               3   north west                    22332      yes  extended
# 4               4   north west                     9025       no   premium
# ...           ...          ...                      ...      ...       ...
# 10684       10684      central                    15563       no   premium
# 10685       10685   north west                     5259       no     basic
# 10686       10686      central                    23893       no  extended
# 10687       10687  west region                    11971       no   premium
# 10688       10688  west region                     6857       no     basic
#
#       education effective_to_date month employment_status gender  ...  \
# 0       college           2/18/11   feb          employed      m  ...
# 1       college           1/18/11   jan        unemployed      f  ...
# 2      bachelor           2/10/11   feb          employed      m  ...
# 3       college           1/11/11   jan          employed      m  ...
# 4      bachelor           1/17/11   jan     medical leave      f  ...
# ...         ...               ...   ...               ...    ...  ...
# 10684  bachelor           1/19/11   jan        unemployed      f  ...
# 10685   college            1/6/11   jan          employed      f  ...
# 10686  bachelor            2/6/11   feb          employed      f  ...
# 10687   college           2/13/11   feb          employed      f  ...
# 10688  bachelor            1/8/11   jan        unemployed      m  ...
#
#        months_since_policy_inception number_of_open_complaints  \
# 0                                 52                         0
# 1                                 26                         0
# 2                                 31                         0
# 3                                  3                         0
# 4                                 31                         1
# ...                              ...                       ...
# 10684                             40                         2
# 10685                             68                         0
# 10686                             63                         0
# 10687                             27                         4
# 10688                              1                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      9  corporate auto  corporate l3            offer3
# 1                      1   personal auto   personal l3            offer4
# 2                      2   personal auto   personal l3            offer3
# 3                      2  corporate auto  corporate l3            offer2
# 4                      7   personal auto   personal l2            offer1
# ...                  ...             ...           ...               ...
# 10684                  7   personal auto   personal l1            offer3
# 10685                  6   personal auto   personal l3            offer2
# 10686                  2  corporate auto  corporate l3            offer1
# 10687                  6   personal auto   personal l1            offer1
# 10688                  3   personal auto   personal l1            offer4
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size
# 0              agent                 292  four-door car      medsize
# 1        call center                 744  four-door car      medsize
# 2        call center                 480            suv      medsize
# 3             branch                 484  four-door car      medsize
# 4             branch                 707  four-door car      medsize
# ...              ...                 ...            ...          ...
# 10684            web                1214     luxury car      medsize
# 10685         branch                 273  four-door car      medsize
# 10686            web                 381     luxury suv      medsize
# 10687         branch                 618            suv      medsize
# 10688            web                1021            suv      medsize
#
# [10689 rows x 25 columns]

# %%
df_clean.drop(["Unnamed: 0"], axis=1,inplace=True)
df_clean
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688  west region                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# 0               2/18/11   feb          employed      m   48029  ...
# 1               1/18/11   jan        unemployed      f   26794  ...
# 2               2/10/11   feb          employed      m   22139  ...
# 3               1/11/11   jan          employed      m   49078  ...
# 4               1/17/11   jan     medical leave      f   23675  ...
# ...                 ...   ...               ...    ...     ...  ...
# 10684           1/19/11   jan        unemployed      f   64811  ...
# 10685            1/6/11   jan          employed      f   61146  ...
# 10686            2/6/11   feb          employed      f   39837  ...
# 10687           2/13/11   feb          employed      f   64195  ...
# 10688            1/8/11   jan        unemployed      m   88784  ...
#
#       months_since_policy_inception number_of_open_complaints  \
# 0                                52                         0
# 1                                26                         0
# 2                                31                         0
# 3                                 3                         0
# 4                                31                         1
# ...                             ...                       ...
# 10684                            40                         2
# 10685                            68                         0
# 10686                            63                         0
# 10687                            27                         4
# 10688                             1                         0
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 0                       9  corporate auto  corporate l3            offer3
# 1                       1   personal auto   personal l3            offer4
# 2                       2   personal auto   personal l3            offer3
# 3                       2  corporate auto  corporate l3            offer2
# 4                       7   personal auto   personal l2            offer1
# ...                   ...             ...           ...               ...
# 10684                   7   personal auto   personal l1            offer3
# 10685                   6   personal auto   personal l3            offer2
# 10686                   2  corporate auto  corporate l3            offer1
# 10687                   6   personal auto   personal l1            offer1
# 10688                   3   personal auto   personal l1            offer4
#
#        sales_channel total_claim_amount  vehicle_class vehicle_size
# 0              agent                292  four-door car      medsize
# 1        call center                744  four-door car      medsize
# 2        call center                480            suv      medsize
# 3             branch                484  four-door car      medsize
# 4             branch                707  four-door car      medsize
# ...              ...                ...            ...          ...
# 10684            web               1214     luxury car      medsize
# 10685         branch                273  four-door car      medsize
# 10686            web                381     luxury suv      medsize
# 10687         branch                618            suv      medsize
# 10688            web               1021            suv      medsize
#
# [10689 rows x 24 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
#  12  monthly_premium_auto           10689 non-null  int64
#  13  months_since_last_claim        10689 non-null  int64
#  14  months_since_policy_inception  10689 non-null  int64
#  15  number_of_open_complaints      10689 non-null  int64
#  16  number_of_policies             10689 non-null  int64
#  17  policy_type                    10689 non-null  object
#  18  policy                         10689 non-null  object
#  19  renew_offer_type               10689 non-null  object
#  20  sales_channel                  10689 non-null  object
#  21  total_claim_amount             10689 non-null  int64
#  22  vehicle_class                  10689 non-null  object
#  23  vehicle_size                   10689 non-null  object
# dtypes: int64(8), object(16)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Get the numeric data into dataframe called `numerical` and categorical columns in a dataframe called `categoricals`.

# %%
numerical = df_clean.select_dtypes(int)
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   26794                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   64811                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   88784                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# 2                           34                             31
# 3                           10                              3
# 4                           15                             31
# ...                        ...                            ...
# 10684                        8                             40
# 10685                        7                             68
# 10686                       11                             63
# 10687                        0                             27
# 10688                       31                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                              0                   9                 292
# 1                              0                   1                 744
# 2                              0                   2                 480
# 3                              0                   2                 484
# 4                              1                   7                 707
# ...                          ...                 ...                 ...
# 10684                          2                   7                1214
# 10685                          0                   6                 273
# 10686                          0                   2                 381
# 10687                          4                   6                 618
# 10688                          0                   3                1021
#
# [10689 rows x 8 columns]

# %%
categoricals = df_clean.select_dtypes(object)
categoricals
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688  west region       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# 0              employed      m      suburban        married  corporate auto
# 1            unemployed      f      suburban         single   personal auto
# 2              employed      m      suburban         single   personal auto
# 3              employed      m      suburban         single  corporate auto
# 4         medical leave      f      suburban        married   personal auto
# ...                 ...    ...           ...            ...             ...
# 10684        unemployed      f      suburban        married   personal auto
# 10685          employed      f         urban        married   personal auto
# 10686          employed      f         rural        married  corporate auto
# 10687          employed      f         urban       divorced   personal auto
# 10688        unemployed      m      suburban         single   personal auto
#
#              policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0      corporate l3           offer3         agent  four-door car      medsize
# 1       personal l3           offer4   call center  four-door car      medsize
# 2       personal l3           offer3   call center            suv      medsize
# 3      corporate l3           offer2        branch  four-door car      medsize
# 4       personal l2           offer1        branch  four-door car      medsize
# ...             ...              ...           ...            ...          ...
# 10684   personal l1           offer3           web     luxury car      medsize
# 10685   personal l3           offer2        branch  four-door car      medsize
# 10686  corporate l3           offer1           web     luxury suv      medsize
# 10687   personal l1           offer1        branch            suv      medsize
# 10688   personal l1           offer4           web            suv      medsize
#
# [10689 rows x 16 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
#  12  monthly_premium_auto           10689 non-null  int64
#  13  months_since_last_claim        10689 non-null  int64
#  14  months_since_policy_inception  10689 non-null  int64
#  15  number_of_open_complaints      10689 non-null  int64
#  16  number_of_policies             10689 non-null  int64
#  17  policy_type                    10689 non-null  object
#  18  policy                         10689 non-null  object
#  19  renew_offer_type               10689 non-null  object
#  20  sales_channel                  10689 non-null  object
#  21  total_claim_amount             10689 non-null  int64
#  22  vehicle_class                  10689 non-null  object
#  23  vehicle_size                   10689 non-null  object
# dtypes: int64(8), object(16)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Check the normality of the numerical variables visually

# %% [markdown]
# ### Use seaborn library to construct distribution plots for the numerical variables

# %%
sns.displot(numerical, bins=20)

# %% [markdown]
# sns.displot(numerical["customer_lifetime_value"],bins=20)

# %% [markdown]
# ### Use Matplotlib to construct histograms

# %%
plt.hist(numerical["customer_lifetime_value"])
# Out:
# (array([8.497e+03, 1.399e+03, 4.800e+02, 1.750e+02, 9.000e+01, 2.500e+01,
#         1.400e+01, 5.000e+00, 3.000e+00, 1.000e+00]),
#  array([ 1898. , 10040.7, 18183.4, 26326.1, 34468.8, 42611.5, 50754.2,
#         58896.9, 67039.6, 75182.3, 83325. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(2,2 ,figsize=(10, 10))
plt.suptitle("These are some histograms", fontsize=16)

ax[0,0].hist(numerical["customer_lifetime_value"], color = "green")
ax[0,0].set_title('Customer lifetime value', fontsize=15)

ax[0,1].hist(numerical["income"])
ax[0,1].set_title('Income', fontsize=15)

ax[1,0].hist(numerical["monthly_premium_auto"],color = "yellow")
ax[1,0].set_title('Monthly premium auto', fontsize=15)

ax[1,1].hist(numerical["months_since_last_claim"],color = "pink")
ax[1,1].set_title('Months since last claim', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Months since last claim')

# %% [markdown]
#  ### Do the distributions for different numerical variables look like a normal distribution?

# %%
sns.displot(numerical["customer_lifetime_value"],  kde=True)

# %%
import scipy 
scipy.stats.normaltest(numerical["customer_lifetime_value"])
# Out:
# NormaltestResult(statistic=7031.944548960842, pvalue=0.0)

# %% [markdown]
# ### Check the multicollinearity of the numerical variables

# %%
sns.heatmap(numerical.corr())
# Out:
# <AxesSubplot:>

# %%
corr = numerical.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
#As we don't have a lot of correlation, I'm going to keep all the features.

# %% [markdown]
# ## Activity 5

# %% [markdown]
# ### Show a plot of the total number of responses.

# %%
df_clean["response"].hist()
# Out:
# <AxesSubplot:>

# %%
#we use countplot to bin categorical
sns.countplot(x="response", data=df_clean)
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
df_clean
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688  west region                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# 0               2/18/11   feb          employed      m   48029  ...
# 1               1/18/11   jan        unemployed      f   26794  ...
# 2               2/10/11   feb          employed      m   22139  ...
# 3               1/11/11   jan          employed      m   49078  ...
# 4               1/17/11   jan     medical leave      f   23675  ...
# ...                 ...   ...               ...    ...     ...  ...
# 10684           1/19/11   jan        unemployed      f   64811  ...
# 10685            1/6/11   jan          employed      f   61146  ...
# 10686            2/6/11   feb          employed      f   39837  ...
# 10687           2/13/11   feb          employed      f   64195  ...
# 10688            1/8/11   jan        unemployed      m   88784  ...
#
#       months_since_policy_inception number_of_open_complaints  \
# 0                                52                         0
# 1                                26                         0
# 2                                31                         0
# 3                                 3                         0
# 4                                31                         1
# ...                             ...                       ...
# 10684                            40                         2
# 10685                            68                         0
# 10686                            63                         0
# 10687                            27                         4
# 10688                             1                         0
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 0                       9  corporate auto  corporate l3            offer3
# 1                       1   personal auto   personal l3            offer4
# 2                       2   personal auto   personal l3            offer3
# 3                       2  corporate auto  corporate l3            offer2
# 4                       7   personal auto   personal l2            offer1
# ...                   ...             ...           ...               ...
# 10684                   7   personal auto   personal l1            offer3
# 10685                   6   personal auto   personal l3            offer2
# 10686                   2  corporate auto  corporate l3            offer1
# 10687                   6   personal auto   personal l1            offer1
# 10688                   3   personal auto   personal l1            offer4
#
#        sales_channel total_claim_amount  vehicle_class vehicle_size
# 0              agent                292  four-door car      medsize
# 1        call center                744  four-door car      medsize
# 2        call center                480            suv      medsize
# 3             branch                484  four-door car      medsize
# 4             branch                707  four-door car      medsize
# ...              ...                ...            ...          ...
# 10684            web               1214     luxury car      medsize
# 10685         branch                273  four-door car      medsize
# 10686            web                381     luxury suv      medsize
# 10687         branch                618            suv      medsize
# 10688            web               1021            suv      medsize
#
# [10689 rows x 24 columns]

# %% [markdown]
# ### Show a plot of the response rate by the sales channel.

# %%
sns.countplot(x="sales_channel", data=df_clean)
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='count'>

# %%
sns.countplot(x="sales_channel",hue="response",data=df_clean)
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='count'>

# %% [markdown]
# ### Show a plot of the response rate by the total claim amount.

# %%
sns.countplot(x="total_claim_amount", data=df_clean)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='count'>

# %%
sns.countplot(x="total_claim_amount", hue="response" data=df_clean)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='count'>

# %%
#as we have a lot of differents total claim amount, it has no sense tot make a countplot, but we can bin them.

# %%
df_clean["total_claim_amount"].max()
# Out:
# 2893

# %%
df_clean["total_claim_amount"].hist()
# Out:
# <AxesSubplot:>

# %%
#We are going to define the bins as low, medium, high and very high

# %%
bins = [0, 500, 1000, 1500, 3000]
labels = ["low", "medium", "high", "very high"]
df_clean['total_claim_binned'] = pd.cut(df_clean["total_claim_amount"], bins, labels = labels)
sns.countplot(x="total_claim_binned",hue="response",data=df_clean)
# Out:
# <AxesSubplot:xlabel='total_claim_binned', ylabel='count'>

# %%
df_clean
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688  west region                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# 0               2/18/11   feb          employed      m   48029  ...
# 1               1/18/11   jan        unemployed      f   26794  ...
# 2               2/10/11   feb          employed      m   22139  ...
# 3               1/11/11   jan          employed      m   49078  ...
# 4               1/17/11   jan     medical leave      f   23675  ...
# ...                 ...   ...               ...    ...     ...  ...
# 10684           1/19/11   jan        unemployed      f   64811  ...
# 10685            1/6/11   jan          employed      f   61146  ...
# 10686            2/6/11   feb          employed      f   39837  ...
# 10687           2/13/11   feb          employed      f   64195  ...
# 10688            1/8/11   jan        unemployed      m   88784  ...
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      9  corporate auto  corporate l3            offer3
# 1                      1   personal auto   personal l3            offer4
# 2                      2   personal auto   personal l3            offer3
# 3                      2  corporate auto  corporate l3            offer2
# 4                      7   personal auto   personal l2            offer1
# ...                  ...             ...           ...               ...
# 10684                  7   personal auto   personal l1            offer3
# 10685                  6   personal auto   personal l3            offer2
# 10686                  2  corporate auto  corporate l3            offer1
# 10687                  6   personal auto   personal l1            offer1
# 10688                  3   personal auto   personal l1            offer4
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 0              agent                 292  four-door car      medsize
# 1        call center                 744  four-door car      medsize
# 2        call center                 480            suv      medsize
# 3             branch                 484  four-door car      medsize
# 4             branch                 707  four-door car      medsize
# ...              ...                 ...            ...          ...
# 10684            web                1214     luxury car      medsize
# 10685         branch                 273  four-door car      medsize
# 10686            web                 381     luxury suv      medsize
# 10687         branch                 618            suv      medsize
# 10688            web                1021            suv      medsize
#
#              binned total_claim_binned
# 0         (0, 1000]                low
# 1         (0, 1000]                low
# 2         (0, 1000]                low
# 3         (0, 1000]                low
# 4         (0, 1000]                low
# ...             ...                ...
# 10684  (1000, 2000]             medium
# 10685     (0, 1000]                low
# 10686     (0, 1000]                low
# 10687     (0, 1000]                low
# 10688  (1000, 2000]             medium
#
# [10689 rows x 26 columns]

# %% [markdown]
# ## Show a plot of the response rate by income.

# %%
df_clean["income"].hist()
# Out:
# <AxesSubplot:>

# %%
df_clean["income"].max()
# Out:
# 99981

# %%
income_bins = [0, 30000, 60000, 80000, 100000]
income_labels = ["low", "medium", "high", "very high"]
df_clean['income_binned'] = pd.cut(df_clean["income"], bins = income_bins, labels = income_labels)
sns.countplot(x="income_binned",hue="response",data=df_clean)
# Out:
# <AxesSubplot:xlabel='income_binned', ylabel='count'>

# %%
sns.countplot(x="total_claim_binned",hue="response",data=df_clean)
# Out:
# <AxesSubplot:xlabel='total_claim_binned', ylabel='count'>

# %%
fig, ax = plt.subplots(2,2 ,figsize=(10, 10))
plt.suptitle("These are some histograms", fontsize=16)

ax[0,0].plot(numerical["customer_lifetime_value"])
ax[0,0].set_title('Customer lifetime value', fontsize=15)

ax[0,1].plot(numerical["income"])
ax[0,1].set_title('Income', fontsize=15)

ax[1,0].plot(numerical["monthly_premium_auto"])
ax[1,0].set_title('Monthly premium auto', fontsize=15)

ax[1,1].plot(numerical["months_since_last_claim"])
ax[1,1].set_title('Months since last claim', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Months since last claim')

# %%
axs[0].hist(dist1, bins=n_bins)
axs[1].hist(dist2, bins=n_bins)

# %%
fig1=plt.hist(numerical["customer_lifetime_value"])
plt.subplot(2,2,1)
#plt.plot(fig1, label='y = 2x')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(2,2,figsize = (12,10))

# %%
# create first figure and ax
fig=plt.figure(figsize = (10,8)) # (12,10)

# we add a title to the figure or the ax
#ax.set_title('My first Matplotlib plot', fontsize=18)
plt.subplot(1,1,1)
plt.title('My first Matplotlib plot', fontsize=18)
# we plot the different lines adding them to the axis
plt.plot(x,y1, label='y = 2x')
plt.plot(x,y2, c='red', label='y = x')
plt.plot(x,y3, c='green', label='y = x/2')
plt.plot(x,y4, c='orange', label='y = 3x')

# we add the legend
plt.legend()

# %%
numerical.hist(figsize=(12,12))
# Out:
# /home/dani/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.displot(numerical)
