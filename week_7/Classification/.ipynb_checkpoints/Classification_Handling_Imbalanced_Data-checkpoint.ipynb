# %% [markdown]
# ## Classification.  Handling Imbalanced Data

# %% [markdown]
# ## Scenario
# You are working as an analyst with this internet service provider. You are provided with this historical data about your company's customers and their churn trends. Your task is to build a machine learning model that will help the company identify customers that are more likely to default/churn and thus prevent losses from such customers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.set_option('display.max_rows', 200)

# %%
churnData = pd.read_csv("DATA_Customer-Churn.csv")

# %%
churnData.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract  MonthlyCharges TotalCharges Churn
# 0              No  Month-to-month           29.85        29.85    No
# 1              No        One year           56.95       1889.5    No
# 2              No  Month-to-month           53.85       108.15   Yes
# 3              No        One year           42.30      1840.75    No
# 4              No  Month-to-month           70.70       151.65   Yes

# %% [markdown]
# ## Check the datatypes of all the columns in the data

# %%
churnData.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ### Converting TotalCharges column into numeric type

# %%
#churnData["TotalCharges"] = pd.to_numeric(churnData["TotalCharges"])
#We find some errors on that column (empty values, not NaN)

# %%
churnData.loc[488, 'TotalCharges']
# Out:
# ' '

# %%
#If ‘coerce’, then invalid parsing will be set as NaN.
churnData["TotalCharges"] = pd.to_numeric(churnData["TotalCharges"], errors='coerce')

# %% [markdown]
# ### Check for null values and replace them

# %%
churnData.isnull().values.any()
# Out:
# True

# %%
round(churnData.isna().sum()/len(churnData),4)*100
# Out:
# gender              0.00
# SeniorCitizen       0.00
# Partner             0.00
# Dependents          0.00
# tenure              0.00
# PhoneService        0.00
# OnlineSecurity      0.00
# OnlineBackup        0.00
# DeviceProtection    0.00
# TechSupport         0.00
# StreamingTV         0.00
# StreamingMovies     0.00
# Contract            0.00
# MonthlyCharges      0.00
# TotalCharges        0.16
# Churn               0.00
# dtype: float64

# %%
churnData=churnData.fillna(churnData.mean())

# %%
churnData["TotalCharges"].mean()
# Out:
# 2283.3004408418697

# %%
churnData["TotalCharges"][churnData["TotalCharges"] > 0].mean()
# Out:
# 2283.3004408418697

# %%
round(churnData.isna().sum()/len(churnData),4)*100
# Out:
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
churnData["Churn"] = churnData["Churn"].replace(('Yes','No'),(1,0))
churnData["Churn"]
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %% [markdown]
# ### Split the data into a training set and a test set just using 4 features

# %%
X = churnData[['tenure', 'SeniorCitizen', 'MonthlyCharges','TotalCharges']]
y = churnData["Churn"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=11)

# %%
X_test
# Out:
#       tenure  SeniorCitizen  MonthlyCharges  TotalCharges
# 6625      12              1           91.30       1094.50
# 5975       7              0           89.75        608.80
# 6891       4              0           29.05        129.60
# 1681      72              0           25.00       1849.20
# 4780       9              0           70.05        657.50
# ...      ...            ...             ...           ...
# 6525      55              0           20.50       1177.95
# 710        1              0           19.55         19.55
# 6639      50              0          103.40       5236.40
# 6844      29              0           89.65       2623.65
# 2736      60              1           89.45       5294.60
#
# [1409 rows x 4 columns]

# %% [markdown]
# ### Fit a logistic Regression model on the training data.

# %%
log_model = LogisticRegression()

# %% [markdown]
# ### Scale the features

# %%
#transform data
trans = StandardScaler()
trans.fit(X_train)
X_train_mod = trans.transform(X_train)
X_test_mod  = trans.transform(X_test)

# %% [markdown]
# - Change again X_train_mod and X_test mod to dataframe

# %%
X_train_mod = pd.DataFrame(X_train_mod, columns= X.columns)
X_test_mod = pd.DataFrame(X_test_mod, columns= X.columns)

# %%
X_train_mod.head()
# Out:
#      tenure  SeniorCitizen  MonthlyCharges  TotalCharges
# 0  0.433427      -0.436885        0.463368      0.518185
# 1 -0.666742      -0.436885       -0.362676     -0.639413
# 2  0.148198       2.288930        0.639193      0.324807
# 3 -1.114959      -0.436885        0.679002     -0.820140
# 4 -1.277947      -0.436885       -1.474021     -0.998111

# %%
#Fitting data
log_model.fit(X_train_mod, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Make Predictions

# %%
y_pred_train_log = log_model.predict(X_train_mod)
y_pred_test_log = log_model.predict(X_test_mod)

# %%
y_pred_train_log
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pred_test_log
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# - We have to state that our positive label is Yes (and negative label is No), instead of 0, which is the default value

# %%
performance_log = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_log),
                                         precision_score(y_train, y_pred_train_log,pos_label =1),
                                         recall_score(y_train, y_pred_train_log,pos_label = 1)],
                               'Test': [accuracy_score(y_test, y_pred_test_log),
                                        precision_score(y_test, y_pred_test_log,pos_label = 1),
                                        recall_score(y_test, y_pred_test_log,pos_label = 1
                                                    )]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_log))
plot_confusion_matrix(log_model,X_train_mod,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_log))
plot_confusion_matrix(log_model,X_test_mod,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.789315  0.801278
# 1    Precision  0.647002  0.691406
# 2       Recall  0.448692  0.468254
# Confusion matrix for the train set
# [[3778  365]
#  [ 822  669]]
# Confusion matrix for the test set
# [[952  79]
#  [201 177]]

# %% [markdown]
# ## Try with KNN CLASSIFIER

# %% [markdown]
# - Fit a Knn Classifier model on the training data. let's start with 3 neighbors

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train_mod, y_train)  #X_train_mod is the scaled version
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
X_train_mod
# Out:
#         tenure  SeniorCitizen  MonthlyCharges  TotalCharges
# 0     0.433427      -0.436885        0.463368      0.518185
# 1    -0.666742      -0.436885       -0.362676     -0.639413
# 2     0.148198       2.288930        0.639193      0.324807
# 3    -1.114959      -0.436885        0.679002     -0.820140
# 4    -1.277947      -0.436885       -1.474021     -0.998111
# ...        ...            ...             ...           ...
# 5629  1.411355      -0.436885        1.538221      2.312446
# 5630  0.392680      -0.436885       -1.493926     -0.632470
# 5631  1.533596      -0.436885        1.382301      2.253468
# 5632  0.351933       2.288930        1.113588      0.838842
# 5633  1.574343      -0.436885       -1.470703     -0.345490
#
# [5634 rows x 4 columns]

# %%
y_train
# Out:
# 5305    0
# 3351    1
# 5177    1
# 1460    1
# 4010    0
#        ..
# 1293    0
# 4023    0
# 5200    0
# 3775    1
# 1945    0
# Name: Churn, Length: 5634, dtype: int64

# %% [markdown]
# ### Make Predictions on KNN

# %%
y_pred_train_knn = neigh.predict(X_train_mod)
y_pred_test_knn = neigh.predict(X_test_mod)

# %%
y_pred_train_knn
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
y_pred_test_knn
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %% [markdown]
# ### Confusion matrix on KNN with k=3

# %%
performance_KNN = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn,pos_label =1),
                                         recall_score(y_train, y_pred_train_knn,pos_label = 1)],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn,pos_label = 1),
                                        recall_score(y_test, y_pred_test_knn,pos_label = 1
                                                    )]})

display(performance_KNN)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train,y_pred_train_knn))
plot_confusion_matrix(neigh,X_train_mod,y_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test, y_pred_test_knn))
plot_confusion_matrix(neigh,X_test_mod,y_test, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.804224  0.799858
# 1    Precision  0.708602  0.696721
# 2       Recall  0.441985  0.449735
# Confusion matrix for the train set
# [[3872  271]
#  [ 832  659]]
# Confusion matrix for the test set
# [[957  74]
#  [208 170]]

# %%
# make predictions
y_pred_train_knn = neigh.predict(X_train_mod)
y_pred_test_knn  = neigh.predict(X_test_mod)

#performance_knn, _, _ = model_performance(y_train, y_pred_train_knn, y_test, y_pred_test_knn)
#performance_knn

# %%
y_pred_train_knn
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# - With 3 neighbors, we have poor results on R2Test. It's possible to have overfitting

# %% [markdown]
# - Let's make a for loop to try others value for k neighbours

# %%
full_knn = pd.DataFrame()

models = {'k': [] }

for k in range(2,30):

    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X_train_mod, y_train)

    models['k'] = [k, neigh]

    y_pred_train_knn = neigh.predict(X_train_mod)
    y_pred_test_knn  = neigh.predict(X_test_mod)
    temp_knn = pd.DataFrame({'k': [k]*3, 'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train, y_pred_train_knn),
                                         precision_score(y_train, y_pred_train_knn,pos_label =1),
                                         recall_score(y_train, y_pred_train_knn,pos_label = 1)],
                               'Test': [accuracy_score(y_test, y_pred_test_knn),
                                        precision_score(y_test, y_pred_test_knn,pos_label = 1),
                                        recall_score(y_test, y_pred_test_knn,pos_label = 1
                                                    )]})
    full_knn = pd.concat([full_knn,temp_knn], axis=0)

full_knn
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.864217  0.766501
# 1   2    Precision  0.991870  0.638418
# 2   2       Recall  0.490946  0.298942
# 0   3     Accuracy  0.862087  0.768630
# 1   3    Precision  0.784236  0.582278
# 2   3       Recall  0.660630  0.486772
# 0   4     Accuracy  0.840966  0.784244
# 1   4    Precision  0.842348  0.663717
# 2   4       Recall  0.490946  0.396825
# 0   5     Accuracy  0.839368  0.781405
# 1   5    Precision  0.743355  0.614379
# 2   5       Recall  0.600268  0.497354
# 0   6     Accuracy  0.828186  0.779986
# 1   6    Precision  0.792179  0.642857
# 2   6       Recall  0.475520  0.404762
# 0   7     Accuracy  0.827654  0.779276
# 1   7    Precision  0.731729  0.617544
# 2   7       Recall  0.550637  0.465608
# 0   8     Accuracy  0.820021  0.784954
# 1   8    Precision  0.766480  0.663755
# 2   8       Recall  0.460094  0.402116
# 0   9     Accuracy  0.818069  0.788502
# 1   9    Precision  0.710289  0.645985
# 2   9       Recall  0.527834  0.468254
# 0  10     Accuracy  0.812389  0.788502
# 1  10    Precision  0.741648  0.666667
# 2  10       Recall  0.446680  0.423280
# 0  11     Accuracy  0.815229  0.789212
# 1  11    Precision  0.712665  0.649446
# 2  11       Recall  0.505701  0.465608
# 0  12     Accuracy  0.811502  0.785664
# 1  12    Precision  0.734940  0.657025
# 2  12       Recall  0.450034  0.420635
# 0  13     Accuracy  0.810969  0.787083
# 1  13    Precision  0.703633  0.645522
# 2  13       Recall  0.493628  0.457672
# 0  14     Accuracy  0.808129  0.791341
# 1  14    Precision  0.725771  0.675000
# 2  14       Recall  0.441985  0.428571
# 0  15     Accuracy  0.810082  0.801987
# 1  15    Precision  0.699905  0.678700
# 2  15       Recall  0.494299  0.497354
# 0  16     Accuracy  0.811679  0.796309
# 1  16    Precision  0.732181  0.678431
# 2  16       Recall  0.454728  0.457672
# 0  17     Accuracy  0.807419  0.794180
# 1  17    Precision  0.694073  0.660584
# 2  17       Recall  0.486922  0.478836
# 0  18     Accuracy  0.808484  0.794180
# 1  18    Precision  0.716842  0.674603
# 2  18       Recall  0.456740  0.449735
# 0  19     Accuracy  0.805467  0.799148
# 1  19    Precision  0.686145  0.671480
# 2  19       Recall  0.488263  0.492063
# 0  20     Accuracy  0.804224  0.799858
# 1  20    Precision  0.708602  0.696721
# 2  20       Recall  0.441985  0.449735
# 0  21     Accuracy  0.804402  0.799858
# 1  21    Precision  0.686840  0.677778
# 2  21       Recall  0.479544  0.484127
# 0  22     Accuracy  0.800852  0.799858
# 1  22    Precision  0.698601  0.703390
# 2  22       Recall  0.435278  0.439153
# 0  23     Accuracy  0.802982  0.800568
# 1  23    Precision  0.685492  0.681648
# 2  23       Recall  0.472166  0.481481
# 0  24     Accuracy  0.800497  0.792761
# 1  24    Precision  0.695838  0.677686
# 2  24       Recall  0.437290  0.433862
# 0  25     Accuracy  0.803337  0.802697
# 1  25    Precision  0.686103  0.685185
# 2  25       Recall  0.473508  0.489418
# 0  26     Accuracy  0.804402  0.792051
# 1  26    Precision  0.714443  0.683983
# 2  26       Recall  0.434608  0.417989
# 0  27     Accuracy  0.800674  0.799858
# 1  27    Precision  0.681818  0.692000
# 2  27       Recall  0.462777  0.457672
# 0  28     Accuracy  0.801739  0.789212
# 1  28    Precision  0.707778  0.681614
# 2  28       Recall  0.427230  0.402116
# 0  29     Accuracy  0.799965  0.793471
# 1  29    Precision  0.681275  0.674699
# 2  29       Recall  0.458753  0.444444

# %%
### Best accuracy
full_knn[full_knn['Error_metric'] == 'Accuracy']
# Out:
#     k Error_metric     Train      Test
# 0   2     Accuracy  0.864217  0.766501
# 0   3     Accuracy  0.862087  0.768630
# 0   4     Accuracy  0.840966  0.784244
# 0   5     Accuracy  0.839368  0.781405
# 0   6     Accuracy  0.828186  0.779986
# 0   7     Accuracy  0.827654  0.779276
# 0   8     Accuracy  0.820021  0.784954
# 0   9     Accuracy  0.818069  0.788502
# 0  10     Accuracy  0.812389  0.788502
# 0  11     Accuracy  0.815229  0.789212
# 0  12     Accuracy  0.811502  0.785664
# 0  13     Accuracy  0.810969  0.787083
# 0  14     Accuracy  0.808129  0.791341
# 0  15     Accuracy  0.810082  0.801987
# 0  16     Accuracy  0.811679  0.796309
# 0  17     Accuracy  0.807419  0.794180
# 0  18     Accuracy  0.808484  0.794180
# 0  19     Accuracy  0.805467  0.799148
# 0  20     Accuracy  0.804224  0.799858
# 0  21     Accuracy  0.804402  0.799858
# 0  22     Accuracy  0.800852  0.799858
# 0  23     Accuracy  0.802982  0.800568
# 0  24     Accuracy  0.800497  0.792761
# 0  25     Accuracy  0.803337  0.802697
# 0  26     Accuracy  0.804402  0.792051
# 0  27     Accuracy  0.800674  0.799858
# 0  28     Accuracy  0.801739  0.789212
# 0  29     Accuracy  0.799965  0.793471

# %%
full_knn_2 = full_knn.melt(id_vars=['k','Error_metric'])
full_knn_2
# Out:
#       k Error_metric variable     value
# 0     2     Accuracy    Train  0.864217
# 1     2    Precision    Train  0.991870
# 2     2       Recall    Train  0.490946
# 3     3     Accuracy    Train  0.862087
# 4     3    Precision    Train  0.784236
# 5     3       Recall    Train  0.660630
# 6     4     Accuracy    Train  0.840966
# 7     4    Precision    Train  0.842348
# 8     4       Recall    Train  0.490946
# 9     5     Accuracy    Train  0.839368
# 10    5    Precision    Train  0.743355
# 11    5       Recall    Train  0.600268
# 12    6     Accuracy    Train  0.828186
# 13    6    Precision    Train  0.792179
# 14    6       Recall    Train  0.475520
# 15    7     Accuracy    Train  0.827654
# 16    7    Precision    Train  0.731729
# 17    7       Recall    Train  0.550637
# 18    8     Accuracy    Train  0.820021
# 19    8    Precision    Train  0.766480
# 20    8       Recall    Train  0.460094
# 21    9     Accuracy    Train  0.818069
# 22    9    Precision    Train  0.710289
# 23    9       Recall    Train  0.527834
# 24   10     Accuracy    Train  0.812389
# 25   10    Precision    Train  0.741648
# 26   10       Recall    Train  0.446680
# 27   11     Accuracy    Train  0.815229
# 28   11    Precision    Train  0.712665
# 29   11       Recall    Train  0.505701
# 30   12     Accuracy    Train  0.811502
# 31   12    Precision    Train  0.734940
# 32   12       Recall    Train  0.450034
# 33   13     Accuracy    Train  0.810969
# 34   13    Precision    Train  0.703633
# 35   13       Recall    Train  0.493628
# 36   14     Accuracy    Train  0.808129
# 37   14    Precision    Train  0.725771
# 38   14       Recall    Train  0.441985
# 39   15     Accuracy    Train  0.810082
# 40   15    Precision    Train  0.699905
# 41   15       Recall    Train  0.494299
# 42   16     Accuracy    Train  0.811679
# 43   16    Precision    Train  0.732181
# 44   16       Recall    Train  0.454728
# 45   17     Accuracy    Train  0.807419
# 46   17    Precision    Train  0.694073
# 47   17       Recall    Train  0.486922
# 48   18     Accuracy    Train  0.808484
# 49   18    Precision    Train  0.716842
# 50   18       Recall    Train  0.456740
# 51   19     Accuracy    Train  0.805467
# 52   19    Precision    Train  0.686145
# 53   19       Recall    Train  0.488263
# 54   20     Accuracy    Train  0.804224
# 55   20    Precision    Train  0.708602
# 56   20       Recall    Train  0.441985
# 57   21     Accuracy    Train  0.804402
# 58   21    Precision    Train  0.686840
# 59   21       Recall    Train  0.479544
# 60   22     Accuracy    Train  0.800852
# 61   22    Precision    Train  0.698601
# 62   22       Recall    Train  0.435278
# 63   23     Accuracy    Train  0.802982
# 64   23    Precision    Train  0.685492
# 65   23       Recall    Train  0.472166
# 66   24     Accuracy    Train  0.800497
# 67   24    Precision    Train  0.695838
# 68   24       Recall    Train  0.437290
# 69   25     Accuracy    Train  0.803337
# 70   25    Precision    Train  0.686103
# 71   25       Recall    Train  0.473508
# 72   26     Accuracy    Train  0.804402
# 73   26    Precision    Train  0.714443
# 74   26       Recall    Train  0.434608
# 75   27     Accuracy    Train  0.800674
# 76   27    Precision    Train  0.681818
# 77   27       Recall    Train  0.462777
# 78   28     Accuracy    Train  0.801739
# 79   28    Precision    Train  0.707778
# 80   28       Recall    Train  0.427230
# 81   29     Accuracy    Train  0.799965
# 82   29    Precision    Train  0.681275
# 83   29       Recall    Train  0.458753
# 84    2     Accuracy     Test  0.766501
# 85    2    Precision     Test  0.638418
# 86    2       Recall     Test  0.298942
# 87    3     Accuracy     Test  0.768630
# 88    3    Precision     Test  0.582278
# 89    3       Recall     Test  0.486772
# 90    4     Accuracy     Test  0.784244
# 91    4    Precision     Test  0.663717
# 92    4       Recall     Test  0.396825
# 93    5     Accuracy     Test  0.781405
# 94    5    Precision     Test  0.614379
# 95    5       Recall     Test  0.497354
# 96    6     Accuracy     Test  0.779986
# 97    6    Precision     Test  0.642857
# 98    6       Recall     Test  0.404762
# 99    7     Accuracy     Test  0.779276
# 100   7    Precision     Test  0.617544
# 101   7       Recall     Test  0.465608
# 102   8     Accuracy     Test  0.784954
# 103   8    Precision     Test  0.663755
# 104   8       Recall     Test  0.402116
# 105   9     Accuracy     Test  0.788502
# 106   9    Precision     Test  0.645985
# 107   9       Recall     Test  0.468254
# 108  10     Accuracy     Test  0.788502
# 109  10    Precision     Test  0.666667
# 110  10       Recall     Test  0.423280
# 111  11     Accuracy     Test  0.789212
# 112  11    Precision     Test  0.649446
# 113  11       Recall     Test  0.465608
# 114  12     Accuracy     Test  0.785664
# 115  12    Precision     Test  0.657025
# 116  12       Recall     Test  0.420635
# 117  13     Accuracy     Test  0.787083
# 118  13    Precision     Test  0.645522
# 119  13       Recall     Test  0.457672
# 120  14     Accuracy     Test  0.791341
# 121  14    Precision     Test  0.675000
# 122  14       Recall     Test  0.428571
# 123  15     Accuracy     Test  0.801987
# 124  15    Precision     Test  0.678700
# 125  15       Recall     Test  0.497354
# 126  16     Accuracy     Test  0.796309
# 127  16    Precision     Test  0.678431
# 128  16       Recall     Test  0.457672
# 129  17     Accuracy     Test  0.794180
# 130  17    Precision     Test  0.660584
# 131  17       Recall     Test  0.478836
# 132  18     Accuracy     Test  0.794180
# 133  18    Precision     Test  0.674603
# 134  18       Recall     Test  0.449735
# 135  19     Accuracy     Test  0.799148
# 136  19    Precision     Test  0.671480
# 137  19       Recall     Test  0.492063
# 138  20     Accuracy     Test  0.799858
# 139  20    Precision     Test  0.696721
# 140  20       Recall     Test  0.449735
# 141  21     Accuracy     Test  0.799858
# 142  21    Precision     Test  0.677778
# 143  21       Recall     Test  0.484127
# 144  22     Accuracy     Test  0.799858
# 145  22    Precision     Test  0.703390
# 146  22       Recall     Test  0.439153
# 147  23     Accuracy     Test  0.800568
# 148  23    Precision     Test  0.681648
# 149  23       Recall     Test  0.481481
# 150  24     Accuracy     Test  0.792761
# 151  24    Precision     Test  0.677686
# 152  24       Recall     Test  0.433862
# 153  25     Accuracy     Test  0.802697
# 154  25    Precision     Test  0.685185
# 155  25       Recall     Test  0.489418
# 156  26     Accuracy     Test  0.792051
# 157  26    Precision     Test  0.683983
# 158  26       Recall     Test  0.417989
# 159  27     Accuracy     Test  0.799858
# 160  27    Precision     Test  0.692000
# 161  27       Recall     Test  0.457672
# 162  28     Accuracy     Test  0.789212
# 163  28    Precision     Test  0.681614
# 164  28       Recall     Test  0.402116
# 165  29     Accuracy     Test  0.793471
# 166  29    Precision     Test  0.674699
# 167  29       Recall     Test  0.444444

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#metrics = ['Mean error',]'Mean absolute error',...]

fig, ax = plt.subplots(1,3, figsize=(30,10))
sns.lineplot(x = 'k', y = 'value', data = full_knn_2[full_knn_2['Error_metric'] == 'Accuracy'], hue = 'variable', ax = ax[0])
ax[0].set_xticks(range(2,31))
ax[0].set_title("Accuracy")
ax[0].legend(loc='lower right')
sns.lineplot(x = 'k', y = 'value', data = full_knn_2[full_knn_2['Error_metric'] == 'Precision'], hue = 'variable', ax = ax[1])
ax[1].set_xticks(range(2,31))
ax[1].set_title("Precison")
ax[1].legend(loc='lower right')
sns.lineplot(x = 'k', y = 'value', data = full_knn_2[full_knn_2['Error_metric'] == 'Recall'], hue = 'variable', ax = ax[2])
ax[2].set_xticks(range(2,31))
ax[2].set_title("Recall")
ax[2].legend(loc='lower right')

# %%
full_knn_2[full_knn_2['k'] == 20]
# Out:
#       k Error_metric variable     value
# 54   20     Accuracy    Train  0.804224
# 55   20    Precision    Train  0.708602
# 56   20       Recall    Train  0.441985
# 138  20     Accuracy     Test  0.799858
# 139  20    Precision     Test  0.696721
# 140  20       Recall     Test  0.449735

# %%
full_knn_2[full_knn_2['k'] == 21]
# Out:
#       k Error_metric variable     value
# 57   21     Accuracy    Train  0.804402
# 58   21    Precision    Train  0.686840
# 59   21       Recall    Train  0.479544
# 141  21     Accuracy     Test  0.799858
# 142  21    Precision     Test  0.677778
# 143  21       Recall     Test  0.484127

# %% [markdown]
# For the moment I'll say 20 k
