# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
df = pd.read_csv("data/vehicles.csv")
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
## Your Code here

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %% [markdown]
# #### Car brand names

# %%
df["Make"].value_counts()
# Out:
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
# BMW                                   1677
# Mercedes-Benz                         1284
# Nissan                                1253
# Volkswagen                            1047
# Mitsubishi                             950
# Mazda                                  915
# Audi                                   890
# Porsche                                862
# Honda                                  836
# Jeep                                   829
# Pontiac                                784
# Subaru                                 781
# Volvo                                  717
# Hyundai                                662
# Chrysler                               641
# Buick                                  537
# Mercury                                532
# ...

# %%
df["Make"].describe()   #there are 127 different brands
# Out:
# count         35952
# unique          127
# top       Chevrolet
# freq           3643
# Name: Make, dtype: object

# %% [markdown]
# Looking if the are some brand names that refers at the same car

# %%
df["Make"].unique()
# Out:
# array(['AM General', 'ASC Incorporated', 'Acura', 'Alfa Romeo',
#        'American Motors Corporation', 'Aston Martin', 'Audi',
#        'Aurora Cars Ltd', 'Autokraft Limited', 'BMW', 'BMW Alpina',
#        'Bentley', 'Bertone', 'Bill Dovell Motor Car Company',
#        'Bitter Gmbh and Co. Kg', 'Bugatti', 'Buick', 'CCC Engineering',
#        'CX Automotive', 'Cadillac', 'Chevrolet', 'Chrysler',
#        'Consulier Industries Inc', 'Dabryan Coach Builders Inc', 'Dacia',
#        'Daewoo', 'Daihatsu', 'Dodge', 'E. P. Dutton, Inc.', 'Eagle',
#        'Environmental Rsch and Devp Corp', 'Evans Automobiles',
#        'Excalibur Autos', 'Federal Coach', 'Ferrari', 'Fiat', 'Fisker',
#        'Ford', 'GMC', 'General Motors', 'Genesis', 'Geo', 'Goldacre',
#        'Grumman Allied Industries', 'Grumman Olson', 'Honda', 'Hummer',
#        'Hyundai', 'Import Foreign Auto Sales Inc',
#        'Import Trade Services', 'Infiniti', 'Isis Imports Ltd', 'Isuzu',
# ...

# %%
#BMW and BMW Alpina
#Dutton
#GMC and General Motors
#PAS Inc - GMC and PAS, Inc
#Saleen and Saleen Performance

# %%
df[df["Make"].str.contains("Dutton")]
# Out:
#                                      Make               Model  Year  \
# 11012                  E. P. Dutton, Inc.       Funeral Coach  1985
# 30164  S and S Coach Company  E.p. Dutton  Funeral Coach  2WD  1984
# 31754    Superior Coaches Div E.p. Dutton  Funeral Coach  2WD  1984
#
#        Engine Displacement  Cylinders     Transmission         Drivetrain  \
# 11012                  4.1        8.0  Automatic 4-spd  Front-Wheel Drive
# 30164                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
# 31754                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 11012     Special Purpose Vehicles   Regular          19.388824        15
# 30164  Special Purpose Vehicle 2WD   Regular          32.961000         9
# 31754  Special Purpose Vehicle 2WD   Regular          32.961000        10
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
df["Make"] = df["Make"].replace(["E. P. Dutton, Inc.",'S and S Coach Company  E.p. Dutton',"Superior Coaches Div E.p. Dutton"], "Dutton")

# %%
df[df["Make"].str.contains("Dutton")]
# Out:
#          Make               Model  Year  Engine Displacement  Cylinders  \
# 11012  Dutton       Funeral Coach  1985                  4.1        8.0
# 30164  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
# 31754  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
#
#           Transmission         Drivetrain                Vehicle Class  \
# 11012  Automatic 4-spd  Front-Wheel Drive     Special Purpose Vehicles
# 30164  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 31754  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11012   Regular          19.388824        15           21            17
# 30164   Regular          32.961000         9           11            10
# 31754   Regular          32.961000        10           11            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 11012               522.764706            1950
# ...

# %% [markdown]
# It's working! Let's replace the other brands

# %%
#BMW and BMW Alpina
df["Make"] = df["Make"].replace(["BMW Alpina"], "BMW")

# %%
df[df["Make"].str.contains("BMW")]
# Out:
#      Make              Model  Year  Engine Displacement  Cylinders  \
# 1398  BMW  128ci Convertible  2010                  3.0        6.0
# 1399  BMW  128ci Convertible  2010                  3.0        6.0
# 1400  BMW  128ci Convertible  2011                  3.0        6.0
# 1401  BMW  128ci Convertible  2011                  3.0        6.0
# 1402  BMW  128ci Convertible  2012                  3.0        6.0
# ...   ...                ...   ...                  ...        ...
# 3073  BMW                 i8  2015                  1.5        3.0
# 3074  BMW                 i8  2016                  1.5        3.0
# 3075  BMW                 B7  2007                  4.4        8.0
# 3076  BMW                 B7  2008                  4.4        8.0
# 3077  BMW        Roadster V8  2003                  4.8        8.0
#
#          Transmission        Drivetrain    Vehicle Class  \
# 1398   Automatic (S6)  Rear-Wheel Drive  Subcompact Cars
# ...

# %%
#GMC and General Motors
df["Make"] = df["Make"].replace(["GMC"], "General Motors")

# %%
#PAS Inc - GMC and PAS, Inc
df["Make"] = df["Make"].replace(["PAS Inc - GMC", "PAS, Inc" ], "PAS")

# %%
#Saleen and Saleen Performance
df["Make"] = df["Make"].replace(["Saleen Performance" ], "Saleen")

# %%
df["Make"].describe()  #we have reduce from 127 brands to 121
# Out:
# count         35952
# unique          121
# top       Chevrolet
# freq           3643
# Name: Make, dtype: object

# %% [markdown]
# - Convert CO2 Emissions from Grams/Mile to Grams/Km

# %%
df["CO2 Emission Grams/Km"] = list(map(lambda x:x/1.60934,df["CO2 Emission Grams/Mile"]))
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .

# %%
df["Automatic"] = df["Transmission"].apply(lambda x:1 if x.str.startswtih == "Auto")
# Out:
#   File "<ipython-input-20-71b570cefdc6>", line 1
#     df["Automatic"] = df["Transmission"].apply(lambda x:1 if x.str.startswtih == "Auto")
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
df[df["Transmission"].str.startswith("Auto")]
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35946             smart         fortwo coupe  2012                  1.0
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
df["Automatic"] = np.where(df.Transmission.str.startswith("Auto"), 1, 0)
df["Manual"] = np.where(df.Transmission.str.startswith("Manual"), 1, 0)
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
#df["Automatic"] = np.where(df["Transmission"] == "Auto", 1, 0)
#df["Automatic"] = np.where(df["Transmission"] == "Auto", 1, 0)

# %%
def automatic(row):
    if row.startwith

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
#How many car makers are there? How many models? Which car maker has the most cars in the dataset?
df["Make"].describe()
# Out:
# count         35952
# unique          121
# top       Chevrolet
# freq           3643
# Name: Make, dtype: object

# %%
df["Model"].describe()
# Out:
# count               35952
# unique               3608
# top       F150 Pickup 2WD
# freq                  197
# Name: Model, dtype: object

# %% [markdown]
# - There are 121 car makers and 3608 models. Chevrolet has the most cars in the dataset

# %%
#When were these cars made? --- FROM 1984 TILL 2017

# %%
df["Year"].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
# How big is the engine of these cars? --- FROM 0.6 till 8.4

# %%
df["Engine Displacement"].describe()
# Out:
# count    35952.000000
# mean         3.338493
# std          1.359395
# min          0.600000
# 25%          2.200000
# 50%          3.000000
# 75%          4.300000
# max          8.400000
# Name: Engine Displacement, dtype: float64

# %%
#What's the frequency of different transmissions, drivetrains and fuel types?

# %%
df["Transmission"].value_count()
# Out:
# Automatic 4-spd                     10585
# Manual 5-spd                         7787
# Automatic (S6)                       2631
# Automatic 3-spd                      2597
# Manual 6-spd                         2423
# Automatic 5-spd                      2171
# Automatic 6-spd                      1432
# Manual 4-spd                         1306
# Automatic (S8)                        960
# Automatic (S5)                        822
# Automatic (variable gear ratios)      675
# Automatic 7-spd                       662
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        229
# Auto(AM7)                             157
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           74
# ...

# %%
df["Drivetrain"].value_counts()
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %%
df["Fuel Type"].value_counts()
# Out:
# Regular                        23587
# Premium                         9921
# Gasoline or E85                 1195
# Diesel                           911
# Premium or E85                   121
# Midgrade                          74
# CNG                               60
# Premium and Electricity           20
# Gasoline or natural gas           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %%
#What's the car that consumes the least/most fuel?
df[df["Fuel Barrels/Year"]==df["Fuel Barrels/Year"].max()]
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 20894  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20895  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20896  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20897  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20898  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20894          47.087143         6           10             7
# ...

# %%
df[df["Fuel Barrels/Year"]==df["Fuel Barrels/Year"].min()]
# Out:
#         Make              Model  Year  Engine Displacement  Cylinders  \
# 17395  Honda  Civic Natural Gas  2012                  1.8        4.0
# 17396  Honda  Civic Natural Gas  2013                  1.8        4.0
# 17397  Honda  Civic Natural Gas  2014                  1.8        4.0
# 17398  Honda  Civic Natural Gas  2015                  1.8        4.0
#
#           Transmission         Drivetrain Vehicle Class Fuel Type  \
# 17395  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17396  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17397  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17398  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 17395               0.06        27           38            31
# 17396               0.06        27           38            31
# 17397               0.06        27           38            31
# ...

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
df["CO2 Emission Grams/Km"].sort_values()
# Out:
# 3071      22.990791
# 3069      24.854909
# 3070      24.854909
# 7916      31.690010
# 7917      31.690010
#             ...
# 20897    788.877073
# 20894    788.877073
# 20898    788.877073
# 20896    788.877073
# 20895    788.877073
# Name: CO2 Emission Grams/Km, Length: 35952, dtype: float64

# %%
df.

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here
